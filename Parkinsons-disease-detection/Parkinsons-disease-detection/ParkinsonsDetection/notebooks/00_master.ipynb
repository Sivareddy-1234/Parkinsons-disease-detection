# %% [markdown]
# # Week 1: Environment Setup & Data Acquisition
# **Author:** Gayathri
# **Goal:** Mount Google Drive, set up paths, import all libraries, and verify dataset availability.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Set Project Path
# Define the path to your project folder in Google Drive.
# **Important:** Adjust the path if your folder name differs.

# %%
import os

# Update this path to match your Drive structure
project_path = '/content/drive/MyDrive/ParkinsonsProject/ParkinsonsDetection'
os.chdir(project_path)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content/drive/MyDrive/ParkinsonsProject/ParkinsonsDetection

# %% [markdown]
# ## Install Missing Libraries (if needed)
# Run the following only once to ensure all packages are available.

# %%
# !pip install imbalanced-learn shap

# %% [markdown]
# ## Import All Required Libraries
# We'll import everything we might need throughout the project.

# %% [markdown]
# Update scikit-learn

# %%
# Upgrade scikit-learn to latest version
# !pip install --upgrade scikit-learn

# %%
# Standard data science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn modules
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, confusion_matrix, classification_report,
                             roc_curve)

#  FIX: calibration_curve comes from sklearn.calibration, not sklearn.metrics
from sklearn.calibration import calibration_curve

# Feature selection
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif, RFE

# Imbalanced learning
from imblearn.over_sampling import SMOTE

# Model interpretation
import shap

# Utilities
import joblib
import warnings
warnings.filterwarnings('ignore')

print(" All libraries imported successfully.")
# Out:
#  All libraries imported successfully.

# %% [markdown]
# ## Verify Dataset
# Check that the raw dataset exists in the correct location.

# %%
# List files in data/raw
# !ls data/raw/
# Out:
# parkinsons.csv

# %% [markdown]
# ## Done
# The `parkinsons.csv` listed, now ready for Week 2.
